# %%
import pandas as pd
from datetime import datetime as dt
from boto3 import s3 as s3
import logging

# %%
response = s3.client.get_bucket_logging(
    Bucket='carldata',
    ExpectedBucketOwner = '142762945251'
)
print(response)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-b328fd1b414b> in <module>
# ----> 1 response = s3.client.get_bucket_logging(
#       2     Bucket='carldata',
#       3     ExpectedBucketOwner = '142762945251'
#       4 )
#       5 print(response)
#
# AttributeError: module 'boto3.s3' has no attribute 'client'

# %%
excel = pd.read_excel(file, index_col=False)
temp = pd.DataFrame(excel)
temp = temp.loc[:,['Client', 'Recd Date', 'Item/Product #', 'Material', 'Vendor', 'LPI Lot Number',
                   'MFG Lot Number', 'Exp/Retest Date', 'Initial Balance', 'UOM', 'Balance']]

# %%
tests = temp['Exp/Retest Date'].astype(str)
dates = []
for test in tests:
    dates.append(test[:-9])

temp['Exp/Retest Date']= dates
temp.head()

# %%
tests = temp['Recd Date'].astype(str)
dates = []
for test in tests:
    dates.append(test[:-9])

temp['Recd Date']= dates
temp.head()

# %%
temp = temp.dropna()
temp.head()

# %%
temp = temp[temp['Client'] == 'ELV']
temp.head()
