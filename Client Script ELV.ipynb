# %%
import pandas as pd
import numpy as np
from datetime import datetime as dt
import boto3

# %%
s3 = boto3.client('s3',
                  aws_access_key_id = 'AKIASCPKVVLRRR24MAEI',
                  aws_secret_access_key = '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'
                    )
s3.download_file('carldata', 'Materials_Inventory_Database.xlsx', 'Materials_Inventory_Database.xlsx')
file = 'Materials_Inventory_Database.xlsx'

# %%
excel = pd.read_excel(file, index_col=False)
temp = pd.DataFrame(excel)
temp = temp.loc[:,['Client', 'Recd Date', 'Item/Product #', 'Material', 'Vendor', 'LPI Lot Number',
                   'MFG Lot Number', 'Exp/Retest Date', 'Initial Balance', 'UOM', 'Balance']]

# %%
tests = temp['Exp/Retest Date'].astype(str)
dates = []
for test in tests:
    dates.append(test[:-9])

temp['Exp/Retest Date']= dates
temp.head()
# Out:
#   Client            Recd Date Item/Product #                  Material  \
# 0    CVA  2022-07-18 00:00:00         120710  STD Weigh Boat Med White
# 1    CVA  2022-07-18 00:00:00         120710  STD Weigh Boat Med White
# 2    CVA  2022-07-18 00:00:00         120710  STD Weigh Boat Med White
# 3    CVA  2022-07-18 00:00:00         120710  STD Weigh Boat Med White
# 4    CVA  2022-07-18 00:00:00         120710  STD Weigh Boat Med White
#
#                 Vendor    LPI Lot Number MFG Lot Number Exp/Retest Date  \
# 0  Heathrow Scientific  RM-18072022-0001         519131      2025-01-31
# 1  Heathrow Scientific  RM-18072022-0001         519131      2025-01-31
# 2  Heathrow Scientific  RM-18072022-0001         519131      2025-01-31
# 3  Heathrow Scientific  RM-18072022-0001         519131      2025-01-31
# 4  Heathrow Scientific  RM-18072022-0001         519131      2025-01-31
#
#   Initial Balance  UOM Balance
# 0                  PCS
# 1                  PCS
# 2                  PCS
# 3                  PCS
# 4                  PCS

# %%
tests = temp['Recd Date'].astype(str)
dates = []
for test in tests:
    dates.append(test[:-9])

temp['Recd Date']= dates
temp.head()
# Out:
#   Client   Recd Date Item/Product #                  Material  \
# 0    CVA  2022-07-18         120710  STD Weigh Boat Med White
# 1    CVA  2022-07-18         120710  STD Weigh Boat Med White
# 2    CVA  2022-07-18         120710  STD Weigh Boat Med White
# 3    CVA  2022-07-18         120710  STD Weigh Boat Med White
# 4    CVA  2022-07-18         120710  STD Weigh Boat Med White
#
#                 Vendor    LPI Lot Number MFG Lot Number Exp/Retest Date  \
# 0  Heathrow Scientific  RM-18072022-0001         519131      2025-01-31
# 1  Heathrow Scientific  RM-18072022-0001         519131      2025-01-31
# 2  Heathrow Scientific  RM-18072022-0001         519131      2025-01-31
# 3  Heathrow Scientific  RM-18072022-0001         519131      2025-01-31
# 4  Heathrow Scientific  RM-18072022-0001         519131      2025-01-31
#
#   Initial Balance  UOM Balance
# 0                  PCS
# 1                  PCS
# 2                  PCS
# 3                  PCS
# 4                  PCS

# %%
temp = temp.dropna()
temp.head()
# Out:
#     Client   Recd Date Item/Product #                              Material  \
# 736    ELV  2022-09-09         NF2005       Gelatin Capsules Size 2 (White)
# 737    ELV  2022-09-09         NF5579     Gelatin Capsules Size 00 (Orange)
# 739    ELV  2022-09-21        36103-B  BOTTLE, 3oz (100mL) WM WHITE w/ Caps
# 743    ELV  2022-09-30         NF2005       Gelatin Capsules Size 2 (White)
# 744    ELV  2022-10-11         733317  Microcrystalline (MCC) Pharmacel 102
#
#                Vendor    LPI Lot Number MFG Lot Number Exp/Retest Date  \
# 736    Qualicaps, Inc  RM-09092022-0003       N2102547      2024-09-30
# 737    Qualicaps, Inc  RM-09092022-0004       N2101680      2024-06-30
# 739  Berlin Packaging  RM-21092022-0001  03172022 580C
# 743    Qualicaps, Inc  RM-30092002-0001       N2102547      2024-09-30
# 744        DFE Pharma  RM-11102022-0001         300920      2025-12-31
#
#     Initial Balance    UOM Balance
# 736           23000    PCS    1000
# 737           23000    PCS   12063
# 739             600    PCS       0
# 743           10000    PCS   10000
# 744             500  Grams       0

# %%
temp = temp[temp['Client'] == 'ELV']
temp.head()
# Out:
#     Client   Recd Date Item/Product #                              Material  \
# 736    ELV  2022-09-09         NF2005       Gelatin Capsules Size 2 (White)
# 737    ELV  2022-09-09         NF5579     Gelatin Capsules Size 00 (Orange)
# 739    ELV  2022-09-21        36103-B  BOTTLE, 3oz (100mL) WM WHITE w/ Caps
# 743    ELV  2022-09-30         NF2005       Gelatin Capsules Size 2 (White)
# 744    ELV  2022-10-11         733317  Microcrystalline (MCC) Pharmacel 102
#
#                Vendor    LPI Lot Number MFG Lot Number Exp/Retest Date  \
# 736    Qualicaps, Inc  RM-09092022-0003       N2102547      2024-09-30
# 737    Qualicaps, Inc  RM-09092022-0004       N2101680      2024-06-30
# 739  Berlin Packaging  RM-21092022-0001  03172022 580C
# 743    Qualicaps, Inc  RM-30092002-0001       N2102547      2024-09-30
# 744        DFE Pharma  RM-11102022-0001         300920      2025-12-31
#
#     Initial Balance    UOM Balance
# 736           23000    PCS    1000
# 737           23000    PCS   12063
# 739             600    PCS       0
# 743           10000    PCS   10000
# 744             500  Grams       0
